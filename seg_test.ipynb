# %%
import os
import sys
import tensorflow as tf
slim = tf.contrib.slim
import numpy as np
root_folder = os.path.dirname(os.path.realpath('/media/pravda/New Volume1/LiTS/ct_lits/vol/'))
print(root_folder)
sys.path.append(os.path.abspath(root_folder))
import seg_liver as segmentation
from dataset_segment import Dataset

number_slices = 3

#other Checkpoint_name = 'seg_liver_ck', 'seg_liver.ckpt'

#checkpoint name
task_name = 'segment_liver'


database_root = os.path.join(root_folder, '/media/pravda/New Volume1/LiTS/ct_lits/vol/')
print(root_folder)
logs_path = os.path.join(root_folder, 'training_files', task_name)
result_root = os.path.join(root_folder, 'results')

model_name = os.path.join(logs_path, "seg_liver.ckpt-48000")
test_file = os.path.join(root_folder, 'test.txt')

dataset = Dataset(None, test_file, None, database_root, number_slices, store_memory=False)
result_path = os.path.join(result_root, task_name)
checkpoint_path = model_name
segmentation.test(dataset, checkpoint_path, result_path, number_slices)
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# /media/pravda/New Volume1/LiTS/ct_lits
# /media/pravda/New Volume1/LiTS/ct_lits
# Started loading files...
# Done initializing Dataset
# WARNING:tensorflow:From /media/pravda/New Volume1/liver-segmentation/seg_liver.py:607: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /media/pravda/New Volume1/liver-segmentation/seg_liver.py:611: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# ...
